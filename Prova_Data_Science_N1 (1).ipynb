# %% [markdown]
# # Prova Data Science N1
#
# ## <font color='red'>Importante: a prova é individual.</font>
#
# **Instruções:**
#
# 1. Faça download deste notebook e carregue o mesmo na sua conta do Google Colab.
# 2. Responda às questões propostas.
# 3. Crie um repositório para o notebook, "commite" o notebook neste repositório.
# 4. Na tarefa de avaliação do Teams, envie o link do repositório. Arquivos enviados diretamente no Teams não serão considerados.
# 5. Commits no repositório após a data de entrega (combinada em sala de aula) serão desconsiderados.

# %% [markdown]
# # Objeto da avaliação
#
# Você irá fazer o download do arquivo de dados matches.csv do [repositório do Github](https://raw.githubusercontent.com/mdietterle/repositorio_dados/main/matches.csv)
#
# Todas as questões/atividades serão realizadas com base neste arquivo. É importante que você responda aos questionamentos propostos o mais completo possível, com a maior quantidade de detalhes que você conseguir incluir.
#
# Não se contente com o básico, seja criativo nas respostas, indo além do tradicional.
#
# ## **Importante!!**
#
# Antes de começar a responder, abra o arquivo de dados e entenda o dataset. Não será fornecido um dicionário de dados, é sua tarefa analisar o dataset e "inferir" o que são as colunas e a sua organização.

# %% [markdown]
# ## Instalação de bibliotecas necessárias
#
# Instale neste local todas as bibliotecas necessárias para resolução da avaliação.

# %%
# Instalação de bibliotecas básicas

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %% [markdown]
# ## Estatísticas básicas do dataset
#
#
# Carregue o arquivo de dados no notebook e exiba as características básicas do arquivo (shape, tipo de dados, dados ausentes, estatísticas básicas dos dados, etc)

# %%
# Carregando o arquivo CSV diretamente do ambiente de execução local no Colab
df = pd.read_csv('/content/matches.csv')

# Exibindo o shape (dimensão) do dataset
print("Shape do dataset (linhas, colunas):")
print(df.shape)

# Exibindo os tipos de dados de cada coluna
print("\nTipos de dados das colunas:")
print(df.dtypes)

# Verificando dados ausentes
print("\nDados ausentes por coluna:")
print(df.isnull().sum())

# Exibindo as estatísticas básicas (para colunas numéricas)
print("\nEstatísticas básicas dos dados numéricos:")
print(df.describe())

# Exibindo as estatísticas básicas (para colunas categóricas)
print("\nEstatísticas básicas dos dados categóricos:")
print(df.describe(include=['object']))
# Out:
# Shape do dataset (linhas, colunas):
# (1389, 28)
#
# Tipos de dados das colunas:
# Unnamed: 0        int64
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object
#
# Dados ausentes por coluna:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance       696
# captain            0
# formation          0
# referee            0
# match report       0
# notes           1389
# sh                 0
# sot                0
# dist               1
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64
#
# Estatísticas básicas dos dados numéricos:
#         Unnamed: 0           gf           ga           xg          xga  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean     22.771778     1.335493     1.380850     1.304176     1.338445
# std      13.668172     1.274235     1.291049     0.767268     0.789360
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      11.000000     0.000000     0.000000     0.700000     0.700000
# 50%      22.000000     1.000000     1.000000     1.200000     1.200000
# 75%      33.000000     2.000000     2.000000     1.800000     1.800000
# max      59.000000     9.000000     9.000000     4.600000     5.000000
#
#               poss    attendance  notes           sh          sot  \
# count  1389.000000    693.000000    0.0  1389.000000  1389.000000
# mean     49.702664  36089.963925    NaN    12.153348     4.041037
# std      12.401897  17797.991778    NaN     5.268876     2.403866
# min      18.000000   2000.000000    NaN     0.000000     0.000000
# 25%      40.000000  24351.000000    NaN     8.000000     2.000000
# 50%      50.000000  32061.000000    NaN    12.000000     4.000000
# 75%      59.000000  52214.000000    NaN    15.000000     5.000000
# max      82.000000  73458.000000    NaN    31.000000    15.000000
#
#               dist           fk           pk        pkatt       season
# count  1388.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean     17.011527     0.455724     0.119510     0.147588  2021.452844
# std       2.988364     0.665389     0.352187     0.387804     0.497951
# min       4.000000     0.000000     0.000000     0.000000  2021.000000
# 25%      15.100000     0.000000     0.000000     0.000000  2021.000000
# 50%      16.900000     0.000000     0.000000     0.000000  2021.000000
# 75%      18.800000     1.000000     0.000000     0.000000  2022.000000
# max      34.900000     4.000000     3.000000     3.000000  2022.000000
#
# Estatísticas básicas dos dados categóricos:
#               date   time            comp        round   day venue result  \
# count         1389   1389            1389         1389  1389  1389   1389
# unique         244     18               1           38     7     2      3
# top     2021-05-23  15:00  Premier League  Matchweek 1   Sat  Away      L
# freq            20    286            1389           39   551   695    548
#
#            opponent      captain formation         referee  match report  \
# count          1389         1389      1389            1389          1389
# unique           23           91        16              23             1
# top     Southampton  Hugo Lloris   4-2-3-1  Anthony Taylor  Match Report
# freq             71           70       344             100          1389
#
#                team
# count          1389
# unique           23
# top     Southampton
# freq             72

# %% [markdown]
# ## Dia da semana com placares mais altos
#
# Crie um gráfico que responda em qual dia da semana os placares foram mais altos. O conceito de "placar mais alto" é a soma dos gols feitos no jogo.
#
# Como a quantidade de jogos não é a mesma em todos os dias da semana (finais de semana tendem a ter mais jogos que em dias da semana - o que resultaria em placares mais altos nestes dias), você deverá encontrar uma forma de equalizar esta diferença na quantidade de jogos.
#
# A resposta deverá ser um gráfico que demonstre claramente o comparativo dos dias.

# %%
# Carregando o arquivo CSV
df = pd.read_csv('/content/matches.csv')  # Se estiver executando no Google Colab e o arquivo estiver no ambiente de execução

# Criando uma nova coluna com o total de gols por jogo
df['total_goals'] = df['gf'] + df['ga']

# Convertendo a coluna de data para o formato datetime
df['date'] = pd.to_datetime(df['date'])

# Extraindo o dia da semana da data
df['day_of_week'] = df['date'].dt.day_name()

# Contando o número de jogos por dia da semana
games_per_day = df.groupby('day_of_week').size()

# Calculando a soma total de gols por dia da semana
total_goals_per_day = df.groupby('day_of_week')['total_goals'].sum()

# Calculando a média de gols por jogo para cada dia da semana
avg_goals_per_game_per_day = total_goals_per_day / games_per_day

# Ordenando os dias da semana para facilitar a leitura
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
avg_goals_per_game_per_day = avg_goals_per_game_per_day.reindex(days_order)

# Criando o gráfico
plt.figure(figsize=(10, 6))
avg_goals_per_game_per_day.plot(kind='bar', color='skyblue')
plt.title('Média de gols por jogo por dia da semana')
plt.ylabel('Média de gols por jogo')
plt.xlabel('Dia da semana')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Capitães
#
# Quantos capitães diferentes cada equipe teve durante a temporada?
#
# Responda em forma de um gráfico comparativo, apresentando os dados o mais claramente possível.

# %%
# Carregando o arquivo CSV
df = pd.read_csv('/content/matches.csv')  # Se estiver executando no Google Colab e o arquivo estiver no ambiente de execução

# Verificando as entradas únicas de capitães por equipe
unique_captains_per_team = df.groupby('team')['captain'].nunique()

# Ordenando os dados para melhor visualização
unique_captains_per_team_sorted = unique_captains_per_team.sort_values(ascending=False)

# Criando o gráfico
plt.figure(figsize=(12, 8))
unique_captains_per_team_sorted.plot(kind='bar', color='teal')
plt.title('Número de Capitães Diferentes por Equipe Durante a Temporada')
plt.ylabel('Número de Capitães Diferentes')
plt.xlabel('Equipe')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Formação Tática
#
# Qual a formação tática mais comum para cada equipe de acordo com o resultado obtido (Ex: para vitórias, a formação mais comum é X, para empates Y e para Z em derrotas).
#
# **Importante** responda de forma que seja possível fazer comparativos entre equipes.
#
# Responda com um gráfico.

# %%
# Carregando o arquivo CSV
df = pd.read_csv('/content/matches.csv')

# Mapeando os resultados para 'Win', 'Draw', 'Loss' como 'W', 'D', 'L'
result_mapping = {'W': 'Win', 'D': 'Draw', 'L': 'Loss'}
df['result'] = df['result'].map(result_mapping)

# Agrupando por equipe, resultado e encontrando as formações mais comuns
common_formations = df.groupby(['team', 'result'])['formation'].agg(lambda x: x.mode()[0]).reset_index()

# Criando uma tabela pivot para melhor visualização dos dados
pivot_formations = common_formations.pivot(index='team', columns='result', values='formation').fillna('')

# Plotando gráfico de barras agrupadas
plt.figure(figsize=(14, 10))
bar_width = 0.25  # Largura da barra

# Posições das barras
r1 = range(len(pivot_formations))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

# Criando as barras
plt.bar(r1, pivot_formations['Win'], color='b', width=bar_width, edgecolor='grey', label='Vitórias')
plt.bar(r2, pivot_formations['Draw'], color='g', width=bar_width, edgecolor='grey', label='Empates')
plt.bar(r3, pivot_formations['Loss'], color='r', width=bar_width, edgecolor='grey', label='Derrotas')

# Adicionando legendas e etiquetas
plt.xlabel('Equipe', fontweight='bold', fontsize=15)
plt.xticks([r + bar_width for r in range(len(pivot_formations))], pivot_formations.index, rotation=90)
plt.ylabel('Formação Tática Mais Comum')
plt.title('Formação Tática Mais Comum por Resultado de Jogo')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Posse de bola
#
# Qual a média de posse de bola da equipe mandante quando ela perdeu o jogo?
#
# Responda em forma de gráfico para poder comparar entre todas as equipes.

# %%
# Carregando o arquivo CSV
df = pd.read_csv('/content/matches.csv')

# Filtrar os jogos em que a equipe mandante perdeu (resultado 'L')
df_lost_games = df[(df['result'] == 'L') & (df['venue'] == 'Home')]

# Calcular a média de posse de bola ('poss') para cada equipe mandante
avg_possession_per_team = df_lost_games.groupby('team')['poss'].mean().reset_index()

# Ordenar os valores para facilitar a visualização no gráfico
avg_possession_per_team = avg_possession_per_team.sort_values(by='poss', ascending=False)

# Criando o gráfico de barras
plt.figure(figsize=(12, 8))
plt.bar(avg_possession_per_team['team'], avg_possession_per_team['poss'], color='teal')
plt.title('Média de Posse de Bola da Equipe Mandante Quando Perdeu o Jogo')
plt.xlabel('Equipe')
plt.ylabel('Média de Posse de Bola (%)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Classificação
#
# Qual a classificação final do campeonato?
#
# Responda em forma de tabela, ordenada do primeiro colocado ao último.
# Você deverá apresentar o brasão do time (pode ser obtido online [aqui](https://logodetimes.com/premier-league/), mas automatize a busca, não salve o logo localmente), o nome, a quantidade de pontos e a posição final no campeonato.
#
# **OBS** Vitória vale 3 pontos, empates 1 ponto e derrota 0 pontos.

# %%
import pandas as pd
import requests
from IPython.display import HTML, Image, display

# Carregar o arquivo CSV
df = pd.read_csv('/content/matches.csv')

# Definir pontos: 3 para vitórias, 1 para empates, 0 para derrotas
df['points'] = df['result'].apply(lambda x: 3 if x == 'W' else (1 if x == 'D' else 0))

# Agrupar por equipe e somar os pontos
team_stats = df.groupby('team').agg({
    'points': 'sum',        # Total de pontos
    'result': lambda x: (x == 'W').sum(),  # Vitórias
    'gf': 'sum',            # Gols feitos (opcional)
    'ga': 'sum'             # Gols sofridos (opcional)
}).rename(columns={'result': 'wins', 'gf': 'goals_for', 'ga': 'goals_against'}).reset_index()

# Ordenar as equipes por pontos (decrescente)
team_stats = team_stats.sort_values(by='points', ascending=False).reset_index(drop=True)

# Adicionar a posição final
team_stats['position'] = team_stats.index + 1

# Configuração da API-Football
api_key = 'd6b9fd8cbc00a4867f105a06b6cc1f4bda6bcd14296825deb8d67fe4a8e96578'  # Substitua pela sua chave de API
api_url = 'https://apiv3.apifootball.com/?action=get_teams&league_id=152&APIkey=' + api_key

# Fazer a requisição para obter dados dos times
response = requests.get(api_url)
data = response.json()


# Criar um dicionário com URLs das logos
logos = {team['team_name']: team['team_badge'] for team in data}

# Verificar o conteúdo do dicionário de logos
print("Dicionário de logos:", logos)

# Adicionar URLs das logos ao DataFrame
team_stats['logo'] = team_stats['team'].map(logos)

# Verificar correspondência entre equipes e logos
for team in team_stats['team'].head():
    print(f"Team: {team}, Logo: {logos.get(team, 'Logo not found')}")

# Corrigir a coluna 'logo' no DataFrame original usando .loc
team_stats.loc[:, 'logo'] = team_stats['logo'].apply(lambda x: f'<img src="{x}" width="50" height="50">' if pd.notnull(x) else '')

# Verificar quantos times têm logos válidas
valid_logos = team_stats['logo'].notnull().sum()
print(f"Times com logo válida: {valid_logos} de {len(team_stats)}")

# Exibir uma amostra da tabela com URLs das logos
def render_images(df):
    return df.to_html(escape=False)

# Mostrar a tabela com logos
HTML(render_images(team_stats[['position', 'team', 'points', 'wins', 'logo']]))
# Out:
# Conteúdo da resposta da API: [{'team_key': '80', 'team_name': 'Manchester City', 'team_country': 'England', 'team_founded': '1880', 'team_badge': 'https://apiv3.apifootball.com/badges/80_manchester-city.jpg', 'venue': {'venue_name': 'Etihad Stadium', 'venue_address': 'Rowsley Street', 'venue_city': 'Manchester', 'venue_capacity': '55097', 'venue_surface': 'grass'}, 'players': [{'player_key': 193952099, 'player_id': '193952099', 'player_image': 'https://apiv3.apifootball.com/badges/players/98658_j-doku.jpg', 'player_name': 'J. Doku', 'player_complete_name': 'Jérémy Baffour Doku', 'player_number': '11', 'player_country': '', 'player_type': 'Forwards', 'player_age': '22', 'player_match_played': '3', 'player_goals': '0', 'player_yellow_cards': '0', 'player_red_cards': '0', 'player_injured': 'No', 'player_substitute_out': '2', 'player_substitutes_on_bench': '0', 'player_assists': '0', 'player_birthdate': '2002-05-27', 'player_is_captain': '0', 'player_shots_total': '2', 'player_goals_conceded': '0', 'player_fouls_committed': '1', 'player_tackles': '4', 'player_blocks': '', 'player_crosses_total': '9', 'player_interceptions': '', 'player_clearances': '1', 'player_dispossesed': '5', 'player_saves': '', 'player_inside_box_saves': '', 'player_duels_total': '35', 'player_duels_won': '22', 'player_dribble_attempts': '19', 'player_dribble_succ': '12', 'player_pen_comm': '', 'player_pen_won': '', 'player_pen_scored': '0', 'player_pen_missed': '0', 'player_passes': '100', 'player_passes_accuracy': '90', 'player_key_passes': '5', 'player_woordworks': '', 'player_rating': '7.36'}, {'player_key': 360186901, 'player_id': '360186901', 'player_image': 'https://apiv3.apifootball.com/badges/players/117972_matheus-nunes.jpg', 'player_name': 'Matheus Nunes', 'player_complete_name': 'Matheus Luiz Nunes', 'player_number': '27', 'player_country': '', 'player_type': 'Midfielders', 'player_age': '26', 'player_match_played': '2', 'player_goals': '0', 'player_yellow_cards': '0', 'player_red_cards': '0', 'player_injured': 'No', 'player_substitute_out': '0', 'player_substitutes_on_bench': '3', 'player_assists': '1', 'player_birthdate': '1998-08-27', 'player_is_captain': '0', 'player_shots_total': '', 'player_goals_conceded': '0', 'player_fouls_committed': '', 'player_tackles': '', 'player_blocks': '1', 'player_crosses_total': '1', 'player_interceptions': '', 'player_clearances': '', 'player_dispossesed': '', 'player_saves': '', 'player_inside_box_saves': '', 'player_duels_total': '2', 'player_duels_won': '2', 'player_dribble_attempts': '1', 'player_dribble_succ': '1', 'player_pen_comm': '', 'player_pen_won': '', 'player_pen_scored': '0', 'player_pen_missed': '0', 'player_passes': '17', 'player_passes_accuracy': '15', 'player_key_passes': '1', 'player_woordworks': '', 'player_rating': '7.70'}, {'player_key': 496282918, 'player_id': '496282918', 'player_image': 'https://apiv3.apifootball.com/badges/players/105525_j-gvardiol.jpg', 'player_name': 'J. Gvardiol', 'player_complete_name': 'Joško Gvardiol', 'player_number': '24', 'player_country': '', 'player_type': 'Defenders', 'player_age': '22', 'player_match_played': '3', 'player_goals': '0', 'player_yellow_cards': '0', 'player_red_cards': '0', 'player_injured': 'No', 'player_substitute_out': '1', 'player_substitutes_on_bench': '0', 'player_assists': '0', 'player_birthdate': '2002-01-23', 'player_is_captain': '0', 'player_shots_total': '2', 'player_goals_conceded': '0', 'player_fouls_committed': '', 'player_tackles': '8', 'player_blocks': '', 'player_crosses_total': '1', 'player_interceptions': '6', 'player_clearances': '6', 'player_dispossesed': '1', 'player_saves': '', 'player_inside_box_saves': '', 'player_duels_total': '19', 'player_duels_won': '16', 'player_dribble_attempts': '4', 'player_dribble_succ': '3', 'player_pen_comm': '', 'player_pen_won': '', 'player_pen_scored': '0', 'player_pen_missed': '0', 'player_passes': '213', 'player_passes_accuracy': '199', 'player_key_passes': '', 'player_woordworks': '',  ...
# Dicionário de logos: {'Manchester City': 'https://apiv3.apifootball.com/badges/80_manchester-city.jpg', 'Liverpool': 'https://apiv3.apifootball.com/badges/84_liverpool.jpg', 'Chelsea': 'https://apiv3.apifootball.com/badges/88_chelsea.jpg', 'Manchester United': 'https://apiv3.apifootball.com/badges/102_manchester-united.jpg', 'Arsenal': 'https://apiv3.apifootball.com/badges/141_arsenal.jpg', 'Leicester City': 'https://apiv3.apifootball.com/badges/155_leicester-city.jpg', 'Tottenham Hotspur': 'https://apiv3.apifootball.com/badges/164_tottenham-hotspur.jpg', 'AFC Bournemouth': 'https://apiv3.apifootball.com/badges/3071_afc-bournemouth.jpg', 'Southampton': 'https://apiv3.apifootball.com/badges/3072_southampton.jpg', 'Everton': 'https://apiv3.apifootball.com/badges/3073_everton.jpg', 'Wolverhampton Wanderers': 'https://apiv3.apifootball.com/badges/3077_wolverhampton-wanderers.jpg', 'Brighton & Hove Albion': 'https://apiv3.apifootball.com/badges/3079_brighton--hove-albion.jpg', 'West Ham United': 'https://apiv3.apifootball.com/badges/3081_west-ham-united.jpg', 'Fulham': 'https://apiv3.apifootball.com/badges/3085_fulham.jpg', 'Brentford': 'https://apiv3.apifootball.com/badges/3086_brentford.jpg', 'Aston Villa': 'https://apiv3.apifootball.com/badges/3088_aston-villa.jpg', 'Nottingham Forest': 'https://apiv3.apifootball.com/badges/3089_nottingham-forest.jpg', 'Newcastle United': 'https://apiv3.apifootball.com/badges/3100_newcastle-united.jpg', 'Ipswich Town': 'https://apiv3.apifootball.com/badges/3121_ipswich-town.jpg', 'Crystal Palace': 'https://apiv3.apifootball.com/badges/3429_crystal-palace.jpg'}
# Team: Manchester City, Logo: https://apiv3.apifootball.com/badges/80_manchester-city.jpg
# Team: Chelsea, Logo: https://apiv3.apifootball.com/badges/88_chelsea.jpg
# Team: Manchester United, Logo: https://apiv3.apifootball.com/badges/102_manchester-united.jpg
# Team: Arsenal, Logo: https://apiv3.apifootball.com/badges/141_arsenal.jpg
# Team: Tottenham Hotspur, Logo: https://apiv3.apifootball.com/badges/164_tottenham-hotspur.jpg
# Times com logo válida: 23 de 23
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>position</th>
#       <th>team</th>
#       <th>points</th>
#       <th>wins</th>
#       <th>logo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Manchester City</td>
#       <td>166</td>
#       <td>52</td>
#       <td><img src="https://apiv3.apifootball.com/badges/80_manchester-city.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Chelsea</td>
#       <td>132</td>
#       <td>38</td>
#       <td><img src="https://apiv3.apifootball.com/badges/88_chelsea.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Manchester United</td>
#       <td>128</td>
#       <td>36</td>
#       <td><img src="https://apiv3.apifootball.com/badges/102_manchester-united.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Arsenal</td>
#       <td>121</td>
#       <td>37</td>
#       <td><img src="https://apiv3.apifootball.com/badges/141_arsenal.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Tottenham Hotspur</td>
#       <td>120</td>
#       <td>36</td>
#       <td><img src="https://apiv3.apifootball.com/badges/164_tottenham-hotspur.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>West Ham United</td>
#       <td>117</td>
#       <td>34</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3081_west-ham-united.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Leicester City</td>
#       <td>108</td>
#       <td>31</td>
#       <td><img src="https://apiv3.apifootball.com/badges/155_leicester-city.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Wolverhampton Wanderers</td>
#       <td>94</td>
#       <td>27</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3077_wolverhampton-wanderers.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Leeds United</td>
#       <td>93</td>
#       <td>26</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>Aston Villa</td>
#       <td>92</td>
#       <td>27</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3088_aston-villa.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>Everton</td>
#       <td>88</td>
#       <td>25</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3073_everton.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>Newcastle United</td>
#       <td>88</td>
#       <td>23</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3100_newcastle-united.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Southampton</td>
#       <td>83</td>
#       <td>21</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3072_southampton.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>Crystal Palace</td>
#       <td>82</td>
#       <td>20</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3429_crystal-palace.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>Brighton and Hove Albion</td>
#       <td>82</td>
#       <td>18</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>Burnley</td>
#       <td>70</td>
#       <td>16</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>Liverpool</td>
#       <td>69</td>
#       <td>20</td>
#       <td><img src="https://apiv3.apifootball.com/badges/84_liverpool.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>Brentford</td>
#       <td>40</td>
#       <td>11</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3086_brentford.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>Fulham</td>
#       <td>28</td>
#       <td>5</td>
#       <td><img src="https://apiv3.apifootball.com/badges/3085_fulham.jpg" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>West Bromwich Albion</td>
#       <td>26</td>
#       <td>5</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td>Sheffield United</td>
#       <td>23</td>
#       <td>7</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>Watford</td>
#       <td>22</td>
#       <td>6</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td>Norwich City</td>
#       <td>21</td>
#       <td>5</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Público
#
# Crie uma visualização que apresente o público total de cada equipe, e também um detalhamento por jogos.
#
# Apresentar os dados usando a técnica "DrillDown" será considerado um "plus". A visualização DrillDown permite que gráficos sejam detalhados com cliques em itens do gráfico.
#
# Um exemplo com tabelas pode ser encontrado [aqui](https://dash.plotly.com/dash-ag-grid/enterprise-master-detail).
#
# Um exemplo usando gráficos pode ser encontrado [aqui](https://community.plotly.com/t/show-and-tell-drill-down-functionality-in-dash-using-callback-context/54403?u=atharvakatre)
